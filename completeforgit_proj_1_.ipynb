# %% [markdown]
# <a href="https://colab.research.google.com/github/godsplan22/completed_projects_datascience/blob/main/completeforgit_proj_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("/content/ministry_p.csv")

# %%
data.head()
# Out:
#                    Department /Ministry  Fund allotted(in ₹crores)
# 0               MINISTRY OF AGRICULTURE                  131531.19
# 1           DEPARTMENT OF ATOMIC ENERGY                   18264.89
# 2            MINISTRY OF AYURVEDA, YOGA                    2970.30
# 3  MINISTRY OF CHEMICALS AND FERTILISER                   80714.94
# 4            MINISTRY OF CIVIL AVIATION                    3224.67

# %%
print(data)
# Out:
#                                  Department /Ministry  \
# 0                             MINISTRY OF AGRICULTURE
# 1                         DEPARTMENT OF ATOMIC ENERGY
# 2                          MINISTRY OF AYURVEDA, YOGA
# 3                MINISTRY OF CHEMICALS AND FERTILISER
# 4                          MINISTRY OF CIVIL AVIATION
# 5                                    MINISTRY OF COAL
# 6                   MINISTRY OF COMMERCE AND INDUSTRY
# 7                           MINISTRY OF COMMUNICATION
# 8                        MINISTRY OF CONSUMER AFFAIRS
# 9                       MINISTRY OF CORPORATE AFFAIRS
# 10                                MINISTRY OF CULTURE
# 11                                MINISTRY OF DEFENCE
# 12    MINISTRY OF DEVELOPMENT OF NORTH EASTERN REGION
# 13                         MINISTRY OF EARTH SCIENCES
# 14                              MINISTRY OF EDUCATION
# 15  MINISTRY OF ELECTRONICS AND INFORMATION TECHNO...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Department /Ministry       56 non-null     object
#  1   Fund allotted(in ₹crores)  56 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.0+ KB

# %%
max_index = data['Fund allotted(in ₹crores)'].idxmax()

# %%
print(max_index)
# Out:
# 56

# %%
max_allotment = data['Fund allotted(in ₹crores)'].max()

# %%
print(max_allotment)
# Out:
# 3483235.63

# %%
department_with_max_allotment = data.loc[data['Fund allotted(in ₹crores)'].idxmax(), 'Department /Ministry']

print(f"Department with the highest allotment: {department_with_max_allotment}")
# Out:
# Department with the highest allotment: GRAND TOTAL

# %%
data.rename(columns={'Fund allotted(in ₹crores)': 'Fund_allotted_in_rupees'}, inplace=True)

# %%
data.head()
# Out:
#                    Department /Ministry  Fund_allotted_in_rupees
# 0               MINISTRY OF AGRICULTURE                131531.19
# 1           DEPARTMENT OF ATOMIC ENERGY                 18264.89
# 2            MINISTRY OF AYURVEDA, YOGA                  2970.30
# 3  MINISTRY OF CHEMICALS AND FERTILISER                 80714.94
# 4            MINISTRY OF CIVIL AVIATION                  3224.67

# %%
department_with_max_allotment = data.loc[data['Fund_allotted_in_rupees'].idxmax(), 'Department /Ministry']

print(f"Department with the highest allotment: {department_with_max_allotment}")
# Out:
# Department with the highest allotment: GRAND TOTAL

# %%
data = data.drop(data.index[-1])

# %%
department_with_max_allotment = data.loc[data['Fund_allotted_in_rupees'].idxmax(), 'Department /Ministry']

print(f"Department with the highest allotment: {department_with_max_allotment}")
# Out:
# Department with the highest allotment: MINISTRY OF FINANCE

# %%
allotment_ministry_finance = data.loc[data['Department /Ministry'] == 'MINISTRY OF FINANCE', 'Fund_allotted_in_rupees'].values[0]

print(f"Allotment to Ministry of Finance: {allotment_ministry_finance}")
# Out:
# Allotment to Ministry of Finance: 1386273.3

# %%
data_Shape=len(data)
print(data_Shape)
# Out:
# 56

# %%
data.head(5)
# Out:
#                    Department /Ministry  Fund_allotted_in_rupees
# 0               MINISTRY OF AGRICULTURE                131531.19
# 1           DEPARTMENT OF ATOMIC ENERGY                 18264.89
# 2            MINISTRY OF AYURVEDA, YOGA                  2970.30
# 3  MINISTRY OF CHEMICALS AND FERTILISER                 80714.94
# 4            MINISTRY OF CIVIL AVIATION                  3224.67

# %%
print(data)
# Out:
#                       Department /Ministry  Fund_allotted_in_rupees
# 0                  MINISTRY OF AGRICULTURE                131531.19
# 8             MINISTRY OF CONSUMER AFFAIRS                256948.40
# 11                     MINISTRY OF DEFENCE                478195.62
# 14                   MINISTRY OF EDUCATION                 93224.31
# 18                     MINISTRY OF FINANCE               1386273.30
# 23                MINISTRY OF HOME AFFAIRS                166546.94
# 41                    MINISTRY OF RAILWAYS                110054.64
# 42  MINISTRY OF ROAD TRANSPORT AND HIGHWAY                118101.00
# 43           MINISTRY OF RURAL DEVELOPMENT                133689.50

# %%
# Append the new row to the existing dataset
data=pd.concat(new_row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-baf04679a88c> in <cell line: 2>()
#       1 # Append the new row to the existing dataset
# ----> 2 data=pd.concat(new_row)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     370         copy = False
#     371
# --> 372     op = _Concatenator(
#     373         objs,
#     374         axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     460                     "only Series and DataFrame objs are valid"
#     461                 )
# --> 462                 raise TypeError(msg)
#     463
#     464             ndims.add(obj.ndim)
#
# ...

# %%
data
# Out:
#                       Department /Ministry  Fund_allotted_in_rupees
# 0                  MINISTRY OF AGRICULTURE                131531.19
# 8             MINISTRY OF CONSUMER AFFAIRS                256948.40
# 11                     MINISTRY OF DEFENCE                478195.62
# 14                   MINISTRY OF EDUCATION                 93224.31
# 18                     MINISTRY OF FINANCE               1386273.30
# 23                MINISTRY OF HOME AFFAIRS                166546.94
# 41                    MINISTRY OF RAILWAYS                110054.64
# 42  MINISTRY OF ROAD TRANSPORT AND HIGHWAY                118101.00
# 43           MINISTRY OF RURAL DEVELOPMENT                133689.50

# %%
drop column
# Out:
# DataFrame after adding new row:
#                      Department /Ministry  Fund_allotted_in_rupees Ministry  \
# 0                 MINISTRY OF AGRICULTURE                131531.19      NaN
# 1            MINISTRY OF CONSUMER AFFAIRS                256948.40      NaN
# 2                     MINISTRY OF DEFENCE                478195.62      NaN
# 3                   MINISTRY OF EDUCATION                 93224.31      NaN
# 4                     MINISTRY OF FINANCE               1386273.30      NaN
# 5                MINISTRY OF HOME AFFAIRS                166546.94      NaN
# 6                    MINISTRY OF RAILWAYS                110054.64      NaN
# 7  MINISTRY OF ROAD TRANSPORT AND HIGHWAY                118101.00      NaN
# 8           MINISTRY OF RURAL DEVELOPMENT                133689.50      NaN
# 9                                     NaN                      NaN   OTHERS
#
#    Expenditure
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...

# %%
df.drop('Ministry', axis=1, inplace=True)

# %%
df.drop('Expenditure', axis=1, inplace=True)

# %%
data
# Out:
#                       Department /Ministry  Fund_allotted_in_rupees
# 0                  MINISTRY OF AGRICULTURE                131531.19
# 8             MINISTRY OF CONSUMER AFFAIRS                256948.40
# 11                     MINISTRY OF DEFENCE                478195.62
# 14                   MINISTRY OF EDUCATION                 93224.31
# 18                     MINISTRY OF FINANCE               1386273.30
# 23                MINISTRY OF HOME AFFAIRS                166546.94
# 41                    MINISTRY OF RAILWAYS                110054.64
# 42  MINISTRY OF ROAD TRANSPORT AND HIGHWAY                118101.00
# 43           MINISTRY OF RURAL DEVELOPMENT                133689.50

# %%
new_row = pd.DataFrame({'Department /Ministry': ['OTHERS'], 'Fund_allotted_in_rupees': [592971.08]})

# Append the new row to the existing DataFrame using pd.concat
df = pd.concat([df, new_row], ignore_index=True)

print("\nDataFrame after adding new row:")
print(df)
# Out:
# DataFrame after adding new row:
#                       Department /Ministry  Fund_allotted_in_rupees
# 0                  MINISTRY OF AGRICULTURE                131531.19
# 1             MINISTRY OF CONSUMER AFFAIRS                256948.40
# 2                      MINISTRY OF DEFENCE                478195.62
# 3                    MINISTRY OF EDUCATION                 93224.31
# 4                      MINISTRY OF FINANCE               1386273.30
# 5                 MINISTRY OF HOME AFFAIRS                166546.94
# 6                     MINISTRY OF RAILWAYS                110054.64
# 7   MINISTRY OF ROAD TRANSPORT AND HIGHWAY                118101.00
# 8            MINISTRY OF RURAL DEVELOPMENT                133689.50
# 9                                   OTHERS                592971.08
# 10                                  OTHERS                592971.08

# %%
df.drop(10, axis=0, inplace=True)

# %%
import pandas as pd

# Sample existing data
data = {
    'Department /Ministry': [
        'MINISTRY OF AGRICULTURE', 'MINISTRY OF CONSUMER AFFAIRS', 'MINISTRY OF DEFENCE',
        'MINISTRY OF EDUCATION', 'MINISTRY OF FINANCE', 'MINISTRY OF HOME AFFAIRS',
        'MINISTRY OF RAILWAYS', 'MINISTRY OF ROAD TRANSPORT AND HIGHWAY', 'MINISTRY OF RURAL DEVELOPMENT'
    ],
    'Fund_allotted_in_rupees': [
        131531.19, 256948.40, 478195.62, 93224.31, 1386273.30, 166546.94, 110054.64, 118101.00, 133689.50
    ]
}
df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)

# Create the new row as a DataFrame
new_row = pd.DataFrame({'Department /Ministry': ['OTHERS'], 'Fund_allotted_in_rupees': [592971.08]})

# Append the new row to the existing dataset using pd.concat
df = pd.concat([df, new_row], ignore_index=True)

print("\nDataFrame after appending new row:")
print(df)
# Out:
# Original DataFrame:
#                      Department /Ministry  Fund_allotted_in_rupees
# 0                 MINISTRY OF AGRICULTURE                131531.19
# 1            MINISTRY OF CONSUMER AFFAIRS                256948.40
# 2                     MINISTRY OF DEFENCE                478195.62
# 3                   MINISTRY OF EDUCATION                 93224.31
# 4                     MINISTRY OF FINANCE               1386273.30
# 5                MINISTRY OF HOME AFFAIRS                166546.94
# 6                    MINISTRY OF RAILWAYS                110054.64
# 7  MINISTRY OF ROAD TRANSPORT AND HIGHWAY                118101.00
# 8           MINISTRY OF RURAL DEVELOPMENT                133689.50
#
# DataFrame after appending new row:
#                      Department /Ministry  Fund_allotted_in_rupees
# 0                 MINISTRY OF AGRICULTURE                131531.19
# 1            MINISTRY OF CONSUMER AFFAIRS                256948.40
# ...

# %%
data.plot.bar(x='Department /Ministry', y='Fund_allotted_in_rupees')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-19c3c9759f9f> in <cell line: 1>()
# ----> 1 data.plot.bar(x='Department /Ministry', y='Fund_allotted_in_rupees')
#
# AttributeError: 'dict' object has no attribute 'plot'

# %%
import pandas as pd

# Convert your dictionary to a DataFrame
df = pd.DataFrame(data)

# Now you can plot
df.plot.bar(x='Department /Ministry', y='Fund_allotted_in_rupees')
# Out:
# <Axes: xlabel='Department /Ministry'>

# %%
df = data["Fund_allotted_in_rupees"]
labels = data["Department /Ministry"]
plt.figure(figsize=(7,7))
plt.pie(df, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, shadow =True)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Distribution of The Budget", fontsize=20)
plt.show()
